# %% [markdown]
# # Aquire and Analyze
# ## eBird
#
# ### Megan Albee, Craig Stahlberg, Jamie Robertson

# %% [markdown]
# This notebook will pull information rougue ornithologists collectively upload into the bird identification app eBird.

# %%
# pip install ebird.api

# %%
# pip install folium

# %%
import requests
import json
import http.client

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import folium 
from folium.plugins import HeatMap 
# %matplotlib inline
sns.set()

# %%
#project blabber put together an api wrapper that is very nice
from ebird.api import get_observations
from ebird.api import get_hotspots, get_nearby_hotspots, get_hotspot
from ebird.api import get_nearby_observations
from ebird.api import get_notable_observations, get_nearby_notable, get_species_observations, get_nearby_species

api_key = 'r6c72jomelh2'

# %%
from ebird.api import get_visits, get_checklist

# %%
import ebird.api

# %%
msla_hotspots = get_nearby_hotspots(api_key, 46.8721500, -113.9940, dist=10)

# %%
horlar = get_species_observations(api_key, 'horlar', 'US-MT')
len(horlar)

# %%
locations.getByCode('US').then((data) => {
    // Metadata for a bird
    console.log(data);

    /*
        {
            countryCode: 'US',
            localAbbrev: 'US',
            name: 'United States',
            nameLong: 'United States of America',
            nameShort: '',
        }
    */
}).catch((error) => {
    console.log(error);
})
# Out:
#   Input In [9]
#     locations.getByCode('US').then((data) => {
#                                     ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
# Get observations from Missoula county
records = get_observations(api_key, 'US-WY', back=30)

# %%
df = pd.DataFrame.from_dict(records)

# %%
df.head(15)
# Out:
#    speciesCode                 comName                sciName      locId  \
# 0       houspa           House Sparrow      Passer domesticus  L21546347
# 1       rocpig             Rock Pigeon          Columba livia  L11312174
# 2       amecro           American Crow  Corvus brachyrhynchos  L11312174
# 3       eucdov  Eurasian Collared-Dove  Streptopelia decaocto  L11312174
# 4       chukar                  Chukar       Alectoris chukar   L9013556
# 5       houfin             House Finch   Haemorhous mexicanus   L4485397
# 6       comrav            Common Raven           Corvus corax   L4485397
# 7       norfli        Northern Flicker       Colaptes auratus   L8268757
# 8       commer        Common Merganser       Mergus merganser   L3271366
# 9      mallar3                 Mallard     Anas platyrhynchos   L3271366
# 10      cangoo            Canada Goose      Branta canadensis   L3271366
# 11      sancra          Sandhill Crane    Antigone canadensis   L8118503
# ...

# %%
df = df.dropna()

# %%
birddens = zip(df['lat'], df['lng'], df['howMany'])
list_of_zip = list(birddens)
list_of_zip[0:10]
# Out:
# [(44.4324346, -109.2368883, 30.0),
#  (41.3017491, -105.5709891, 3.0),
#  (41.3017491, -105.5709891, 4.0),
#  (41.3017491, -105.5709891, 1.0),
#  (44.785512, -108.934677, 8.0),
#  (44.7509582, -108.7673901, 5.0),
#  (44.7509582, -108.7673901, 1.0),
#  (41.303515, -105.565262, 1.0),
#  (43.9738403, -107.9922152, 3.0),
#  (43.9738403, -107.9922152, 2.0)]

# %%
#blank interactive world map
folium_map = folium.Map()
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#street map of Missoula City
missoulacity = [46.8575, -114.0070] #lat,long
folium_map = folium.Map(location=missoulacity, zoom_start = 13, titles = "OpenStreetMap")
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#Okay but now we want to see where the birds are
#A heat map easily tells us the density of birds. 

birds = zip(df['lat'], df['lng'], df['howMany'])
list_of_zip = list(birds)
list_of_zip[0:10]
# Out:
# [(44.4324346, -109.2368883, 30.0),
#  (41.3017491, -105.5709891, 3.0),
#  (41.3017491, -105.5709891, 4.0),
#  (41.3017491, -105.5709891, 1.0),
#  (44.785512, -108.934677, 8.0),
#  (44.7509582, -108.7673901, 5.0),
#  (44.7509582, -108.7673901, 1.0),
#  (41.303515, -105.565262, 1.0),
#  (43.9738403, -107.9922152, 3.0),
#  (43.9738403, -107.9922152, 2.0)]

# %%
hotspots
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 hotspots
#
# NameError: name 'hotspots' is not defined

# %%
hm_layer = HeatMap(list_of_zip,
                   radius = 8)
hm_layer

# %%
folium_hmap = folium.Map(location=missoulacity, zoom_start = 8, titles = "OpenStreetMap")

# %%
folium_hmap.add_child(hm_layer)
folium_hmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import requests

url = "https://api.ebird.org/v2/ref/taxonomy/ebird?species=hottea1&version=2019"

payload={}
headers = {
  'X-eBirdApiToken': '{{x-ebirdapitoken}}'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# SCIENTIFIC_NAME,COMMON_NAME,SPECIES_CODE,CATEGORY,TAXON_ORDER,COM_NAME_CODES,SCI_NAME_CODES,BANDING_CODES,ORDER,FAMILY_COM_NAME,FAMILY_SCI_NAME,REPORT_AS,EXTINCT,EXTINCT_YEAR,FAMILY_CODE
# Spatula hottentota,Blue-billed Teal,hottea1,species,417.0,HOTE BBTE,SPHO,,Anseriformes,"Ducks, Geese, and Waterfowl",Anatidae,,,,anatid1

# %%
url = "https://api.ebird.org/v2/ref/sppgroup/merlin"

payload={}
headers = {
  'X-eBirdApiToken': '{{x-ebirdapitoken}}'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# [{"groupName":"Waterfowl","groupOrder":1,"taxonOrderBounds":[[224.0,739.0]]},{"groupName":"Cormorants and Anhingas","groupOrder":2,"taxonOrderBounds":[[7130.0,7221.0]]},{"groupName":"Loons","groupOrder":3,"taxonOrderBounds":[[6714.0,6723.0]]},{"groupName":"Grebes","groupOrder":4,"taxonOrderBounds":[[1780.0,1854.0]]},{"groupName":"Finfoots","groupOrder":5,"taxonOrderBounds":[[5589.0,5595.0]]},{"groupName":"Penguins","groupOrder":6,"taxonOrderBounds":[[6725.0,6756.0]]},{"groupName":"Alcids","groupOrder":7,"taxonOrderBounds":[[6285.0,6352.0]]},{"groupName":"Albatrosses","groupOrder":8,"taxonOrderBounds":[[6758.0,6792.0]]},{"groupName":"Petrels, Shearwaters, and Diving-Petrels","groupOrder":9,"taxonOrderBounds":[[6866.0,7047.0]]},{"groupName":"Storm-Petrels","groupOrder":10,"taxonOrderBounds":[[6794.0,6864.0]]},{"groupName":"Tropicbirds","groupOrder":11,"taxonOrderBounds":[[6695.0,6712.0]]},{"groupName":"Frigatebirds, Boobies, and Gannets","groupOrder":12,"taxonOrderBounds":[[7083.0,7128
# ...
